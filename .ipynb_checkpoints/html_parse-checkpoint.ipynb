# %%
from bs4 import BeautifulSoup
import re
import json
import warnings
import requests
import openai
import os
warnings.filterwarnings("ignore")

# %%
def extract_info_between_topics(file_path, start_topic, end_topic):
    with open(file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()

    soup = BeautifulSoup(html_content, 'html.parser')

    start_topic_element = soup.find('span', text=start_topic)
    end_topic_element = soup.find('span', text=end_topic)

    content_between = ""

    if start_topic_element and end_topic_element:
        all_elements = soup.find_all(True)

        start_index = all_elements.index(start_topic_element)
        end_index = all_elements.index(end_topic_element)

        for elem in all_elements[start_index + 1:end_index]:
            if elem.name in ['p', 'ul', 'ol']:  
                content_between += elem.get_text(strip=True) + '\n\n'

        filtered_output = re.sub(f'(?m){re.escape(end_topic)}.*$', '', start_topic + '\n\n' + content_between.strip())

    return filtered_output

# %%
file_path = "test1.html"
start_topic = "Business Context and Application"
end_topic = "Expected Outcomes and Benefits"
ref = extract_info_between_topics(file_path, start_topic, end_topic)
print(ref)
# Out:
# Business Context and Application
#
# The Customer 360 Data Product finds application across diverse business contexts, including:
#
# Marketing Optimization: Tailoring marketing campaigns based on customer insights to enhance targeting and campaign effectiveness.
#
# Customer Retention: Implementing proactive retention strategies by identifying at-risk customers and addressing their needs.
#
# Operational Efficiency: Supporting decision-making processes and resource allocation through data-driven insights.
#
# Personalized Customer Experiences: Enabling personalized interactions and experiences by leveraging a deep understanding of individual customer preferences.

# %%
json_ref= json.dumps(ref)
print(json_ref)
# Out:
# "Business Context and Application\n\nThe Customer 360 Data Product finds application across diverse business contexts, including:\n\nMarketing Optimization: Tailoring marketing campaigns based on customer insights to enhance targeting and campaign effectiveness.\n\nCustomer Retention: Implementing proactive retention strategies by identifying at-risk customers and addressing their needs.\n\nOperational Efficiency: Supporting decision-making processes and resource allocation through data-driven insights.\n\nPersonalized Customer Experiences: Enabling personalized interactions and experiences by leveraging a deep understanding of individual customer preferences.\n\n"

# %%
# ref_string = json.dumps(json_ref)

# %%
headers = {
    'accept': 'application/json',
    'apikey': 'dGVzdC5hZTcxZDllYy00NjRmLTQ1NWMtOTc5ZS1jNTMxYzAxNGVlMzc=',
    'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjFjMDg4NjMwYTAzNzUwY2M0NGI2Y2RlZDY5NzcyZjhmYmI5MThiZDEifQ.....qKuOr2gKC5HtPxBayABmihn5Lp2YazmCsLQAhxFFTCtEk9KvauFQoQyBHWyfAdtOauVYilsa-VI6MeJuKZkZY0OtzpLHTG8T5XuMamgYhMbo9BAUhoacy-8_81n-rSZcg-eNgjSX1iUi1h0eMVIn_OGQr2NbqGd2dptSVe_4xdfEmdPNMpoGKR43Gz7NNHDTD7YazDpAk4wkpZmdq0OC-hmNVYqqx-fxqVY1YJh2Ii9N8TlY-5GAWeOdsIqekWZb76-G6cK-HGSnv0ldxsbblIEfrVbToLQemhq0osCzM-1DkFMWg_acV3JOkqqEE0bGB7jlWjmkb61E3EZCR6Ic_A'
}

# %%
url = 'https://cheerful-maggot.dataos.app/lens/api/v1/lenses/account360?original=true'

# %%
info = requests.get(url, headers=headers)

# %%
response_data = info.json()
json_info = json.dumps(response_data)
print(json_info)
# Out:
# {"name": "account360", "contract": "account360", "stack": "minerva", "description": "Data Model to answer any questions around SalesNav details of data product.", "owner": "yogesh", "tags": ["account360"], "published": false, "deleted": false, "updated_at": 1704616449880, "updated_by": "yogeshkhangode", "version": 1, "entities": [{"name": "vip_sales", "sql": {"query": "SELECT\n  uuid(),\n  \"retail_outlet.unique_id\" as unique_id,\n  \"retail_outlet.distributor_id\" as distributor_id,\n  \"sales.distributor_code\" as distributor_code,\n  \"retail_outlet.retailers_account_number\" as retailers_account_number,\n  \"retail_outlet.retailers_doing_business\" as retailers_doing_business,\n  \"retail_outlet.licence_name\" as licence_name,\n  \"retail_outlet.street_address1\" as street_address1,\n  \"retail_outlet.street_address2\" as street_address2,\n  \"retail_outlet.city\" as city,\n  \"retail_outlet.state\" as state,\n  \"retail_outlet.zip_code\" as zip_code,\n  \"retail_outlet.country\
# ...

# %%
# info_string = json.dumps(json_info)

# %%
import json
with open('c360.json', 'r') as json_file:
    data = json.load(json_file)

# %%
def get_value_by_topic(topic, data):
    for item in data:
        if topic in item:
            return item[topic]
    return None

topic = "purpose_and_objectives"
value = get_value_by_topic(topic, data)
print(value)
# Out:
# {'primary_purpose': 'The primary purpose of the Customer 360 Data Product is to equip organizations with a powerful tool that facilitates a nuanced understanding of their customer base.', 'objectives': ['Enhance Customer Engagement: Enable personalized and targeted customer interactions by leveraging insights derived from a 360-degree view of customer profiles.', 'Optimize Marketing Strategies: Facilitate data-driven marketing campaigns, segmentation, and targeting, resulting in improved campaign effectiveness and customer conversion rates.', 'Drive Operational Efficiency: Support decision-making processes by providing actionable insights to various business functions, ultimately improving operational efficiency and resource allocation.', 'Increase Customer Retention and Loyalty: Identify at-risk customers, implement proactive retention strategies, and enhance overall customer satisfaction, fostering loyalty and repeat business.']}

# %%
# !curl -X 'GET' \
  'https://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/78c90f1f-4fff-4604-af41-d117f86da339?include=non-deleted' \
  -H 'accept: application/json' \
  -H 'Authorization: Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjAxNDJkNGM0YjYxYjMzZjBlYjI0OGNhZmExYTZmOTNjMzQxODQ3MzcifQ.....N94llwOMMF2hK-xXoEL4v2o86VVH23LmdHjM-6p9wFcXx38uitkITAAT_g0HjC07ZD5reRguo0vD4PXw8kFC9gKyICUeDIZhVbf2BNkJn0zvEOlTz3SAthPpnOd0RcB7jW2tTHw2sF6Xe8vZEp6QfmFCuBbxw6x3i9SOQkG1Vhb0nSC3T3Uwun6hH7-N6C-smxX5lVTwZrBcC2Scs6K9NwrJ4XH_gj2aRTio1WIpfuO8h71P5W6Su0YM35qejx1eyVVL80IXhqm0sMjaBH6XMRzFszPLTUu5EItVrWxTdD9aRYDOab3VKf-_EUyiFz6HrsMdasy68gmNd8zOv7mljA'
# Out:
# {"id":"78c90f1f-4fff-4604-af41-d117f86da339","name":"campaign-funnel-dp","state":"active","manifestVersion":"v1alpha","displayName":"campaign-funnel-dp","fullyQualifiedName":"campaign-funnel-dp","description":"A structured representation outlining the stages and progression of a marketing campaign's funnel. This overview offers insights into the flow of potential customers through various stages, from awareness to conversion.","version":0.6,"updatedAt":1708517110452,"updatedBy":"yogeshkhangode","href":"http://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/78c90f1f-4fff-4604-af41-d117f86da339","changeDescription":{"fieldsAdded":[{"name":"tags","newValue":"[{\"tagFQN\":\"dataos.dataos:product:data\",\"source\":\"Classification\",\"labelType\":\"Automated\",\"state\":\"Confirmed\"}]"}],"fieldsUpdated":[],"fieldsDeleted":[],"previousVersion":0.5},"deleted":false}

# %%
import requests

url = 'https://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/78c90f1f-4fff-4604-af41-d117f86da339?include=non-deleted'
headers = {
    'accept': 'application/json',
    'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjAxNDJkNGM0YjYxYjMzZjBlYjI0OGNhZmExYTZmOTNjMzQxODQ3MzcifQ.....N94llwOMMF2hK-xXoEL4v2o86VVH23LmdHjM-6p9wFcXx38uitkITAAT_g0HjC07ZD5reRguo0vD4PXw8kFC9gKyICUeDIZhVbf2BNkJn0zvEOlTz3SAthPpnOd0RcB7jW2tTHw2sF6Xe8vZEp6QfmFCuBbxw6x3i9SOQkG1Vhb0nSC3T3Uwun6hH7-N6C-smxX5lVTwZrBcC2Scs6K9NwrJ4XH_gj2aRTio1WIpfuO8h71P5W6Su0YM35qejx1eyVVL80IXhqm0sMjaBH6XMRzFszPLTUu5EItVrWxTdD9aRYDOab3VKf-_EUyiFz6HrsMdasy68gmNd8zOv7mljA'
}

response = requests.get(url, headers=headers)

# %%
info = response.json()
print(info)
# Out:
# {'id': '78c90f1f-4fff-4604-af41-d117f86da339', 'name': 'campaign-funnel-dp', 'state': 'active', 'manifestVersion': 'v1alpha', 'displayName': 'campaign-funnel-dp', 'fullyQualifiedName': 'campaign-funnel-dp', 'description': "A structured representation outlining the stages and progression of a marketing campaign's funnel. This overview offers insights into the flow of potential customers through various stages, from awareness to conversion.", 'version': 0.6, 'updatedAt': 1708517110452, 'updatedBy': 'yogeshkhangode', 'href': 'http://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/78c90f1f-4fff-4604-af41-d117f86da339', 'changeDescription': {'fieldsAdded': [{'name': 'tags', 'newValue': '[{"tagFQN":"dataos.dataos:product:data","source":"Classification","labelType":"Automated","state":"Confirmed"}]'}], 'fieldsUpdated': [], 'fieldsDeleted': [], 'previousVersion': 0.5}, 'deleted': False}

# %%
import openai
import json

openai.api_key = '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'

prompt = f"Existing Value Text: {value}\n\nInfo Text: {info}\n\nConstruct a new value text by incorporating information from the existing value and info."

response = openai.Completion.create(
    engine="gpt-3.5-turbo",
    prompt=prompt,
    max_tokens=200
)

generated_text = response.choices[0].text.strip()

print(generated_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[53], line 8
#       4 openai.api_key = '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'
#       6 prompt = f"Existing Value Text: {value}\n\nInfo Text: {info}\n\nConstruct a new value text by incorporating information from the existing value and info."
# ----> 8 response = openai.Completion.create(
#       9     engine="gpt-3.5-turbo",
#      10     prompt=prompt,
#      11     max_tokens=200
#      12 )
#      14 generated_text = response.choices[0].text.strip()
#      16 print(generated_text)
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
# ...

# %%
# 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

# %%
import openai

# %%
openai.api_key= "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"

# %%
output = openai.Completion.create(
    prompt= "disadvantage of smoking",
    model = "davinci-002",
    max_tokens=50

)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 output = openai.Completion.create(
#       2     prompt= "disadvantage of smoking",
#       3     model = "davinci-002",
#       4     max_tokens=50
#       5
#       6 )
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
# ...

# %%
completion = openai.Completion.create(
        model = "gpt-3.5-turbo",
        messages = [
            {"role":"system", "content":"You are a helpful assistant"},
            {"role":"user", "content": "disadvantage of smoking"},
        ],
        max_tokens = 200,
    )
return completion.choices[0].message.content
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 completion = openai.Completion.create(
#       2         model = "gpt-3.5-turbo",
#       3         messages = [
#       4             {"role":"system", "content":"You are a helpful assistant"},
#       5             {"role":"user", "content": "disadvantage of smoking"},
#       6         ],
#       7         max_tokens = 200,
#       8     )
#       9 return completion.choices[0].message.content
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# ...

# %%
import openai
import json

openai.api_key = 'your-api-key'

prompt = f"Existing Value Text: {value_text}\n\nInfo Text: {info_text}\n\nConstruct a new value text by incorporating information from the existing value text and info text."

response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=prompt,
    max_tokens=200
)

generated_text = response.choices[0].text.strip()

print(generated_text)
