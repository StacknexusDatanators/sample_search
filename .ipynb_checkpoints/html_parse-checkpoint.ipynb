# %%
from bs4 import BeautifulSoup
import re
import json
import warnings
import requests
import openai
import os
warnings.filterwarnings("ignore")

# %%
def extract_info_between_topics(file_path, start_topic, end_topic):
    with open(file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()

    soup = BeautifulSoup(html_content, 'html.parser')

    start_topic_element = soup.find('span', text=start_topic)
    end_topic_element = soup.find('span', text=end_topic)

    content_between = ""

    if start_topic_element and end_topic_element:
        all_elements = soup.find_all(True)

        start_index = all_elements.index(start_topic_element)
        end_index = all_elements.index(end_topic_element)

        for elem in all_elements[start_index + 1:end_index]:
            if elem.name in ['p', 'ul', 'ol']:  
                content_between += elem.get_text(strip=True) + '\n\n'

        filtered_output = re.sub(f'(?m){re.escape(end_topic)}.*$', '', start_topic + '\n\n' + content_between.strip())

    return filtered_output

# %%
file_path = "test1.html"
start_topic = "Business Context and Application"
end_topic = "Expected Outcomes and Benefits"
ref = extract_info_between_topics(file_path, start_topic, end_topic)
print(ref)
# Out:
# Business Context and Application
#
# The Customer 360 Data Product finds application across diverse business contexts, including:
#
# Marketing Optimization: Tailoring marketing campaigns based on customer insights to enhance targeting and campaign effectiveness.
#
# Customer Retention: Implementing proactive retention strategies by identifying at-risk customers and addressing their needs.
#
# Operational Efficiency: Supporting decision-making processes and resource allocation through data-driven insights.
#
# Personalized Customer Experiences: Enabling personalized interactions and experiences by leveraging a deep understanding of individual customer preferences.

# %%
json_ref= json.dumps(ref)
print(json_ref)
# Out:
# "Business Context and Application\n\nThe Customer 360 Data Product finds application across diverse business contexts, including:\n\nMarketing Optimization: Tailoring marketing campaigns based on customer insights to enhance targeting and campaign effectiveness.\n\nCustomer Retention: Implementing proactive retention strategies by identifying at-risk customers and addressing their needs.\n\nOperational Efficiency: Supporting decision-making processes and resource allocation through data-driven insights.\n\nPersonalized Customer Experiences: Enabling personalized interactions and experiences by leveraging a deep understanding of individual customer preferences.\n\n"

# %%
# ref_string = json.dumps(json_ref)

# %% [markdown]
# ## With JSON

# %%
with open('final.json', 'r') as json_file:
    data = json.load(json_file)

# %%
key = "Data Models and Algorithms"
spec = data.get(key)
print(spec)
# Out:
# **Description of Data Models Used**
#
# The Customer 360 Data Product employs a sophisticated blend of data models to construct a comprehensive and unified representation of customer profiles:
#
# 1. Entity-Relationship Model:
#    - Illustrates the relationships and connections between entities, such as customers, transactions, and interactions.
#
# 2. Graph Model:
#    - Captures the intricate connections and dependencies between various elements, providing a visual map of customer relationships and network structures.
#
# 3. Predictive Models:
#    - Harnesses machine learning algorithms, including regression analysis, decision trees, and neural networks, to anticipate customer behaviors and uncover patterns.
#
# 4. Segmentation Models:
#    - Utilizes algorithms like k-means clustering to categorize customers based on shared characteristics, enabling targeted marketing and personalized engagement.
#
# **Algorithms and Analytical Methods**
#
# 1. Predictive Analytics:
# ...

# %%
import requests

url = 'https://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/fdc5c178-8d6f-4bf1-9408-b8467e6f6923'
headers = {
    'accept': 'application/json',
    'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjQ4N2EwZjIzNTA5ZmI1MmIzNDNkMjM3NmQ2YzMzYTc2NTc2YzViYWMifQ.....MbJW-1P1FxwYMBI7i0RkPxC1wehStwFGep_VcNEoJ4DQlXEBbET68rQrboeZAknowToIZ5rjjo4q61f3ShNZBgCAcYer1NHiuOdIeDoVuJs0W-JSPGadv5tyX2s-zIfhSUQNOD9hNlfpSwycbCQfEICcvpVZv1X0dVK_fHBSfLJhe57IEH5so3j5dCkQmLbhn0P3hBkE2iuGlz6PcONuOS-4QtklXJO74PhZ67kIOVFzpQosISXNa7VRWHqfJR8ZmM_Xw0QMW0d1cMKGsm61NBYBeeG5wJgwNwJ1RgXNiRr0NNpqHGMzkWZZ_ydG-cu0lnYAHXAuepisk8EfYX1S5Q'
}

response = requests.get(url, headers=headers)

# %%
info = str(response.json())

print(info)
# Out:
# {'id': 'fdc5c178-8d6f-4bf1-9408-b8467e6f6923', 'name': 'customer-insights-dp', 'state': 'active', 'manifestVersion': 'v1alpha', 'displayName': 'customer-insights-dp', 'fullyQualifiedName': 'customer-insights-dp', 'description': 'This  provides detailed information about customer behavior, preferences, and trends, obtained through thorough data processing methods. It includes comprehensive insights into customer interactions, purchases, demographics, and other relevant metrics, enabling businesses to gain a deep understanding of their customer base and tailor their strategies accordingly.', 'version': 1.8, 'updatedAt': 1708495826831, 'updatedBy': 'yogeshkhangode', 'href': 'http://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/fdc5c178-8d6f-4bf1-9408-b8467e6f6923', 'changeDescription': {'fieldsAdded': [{'name': 'tags', 'newValue': '[{"tagFQN":"dataos.dataos:product:data:customer-insights-dp","source":"Classification","labelType":"Automated","state":"Confirmed"},{"tagFQN":"dataos.
# ...

# %%
from openai import OpenAI

# %%
client = OpenAI(api_key='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')

# %%
response = client.chat.completions.create(
    model="gpt-4-1106-preview",
    messages=[
#         {"role": "system", "content": f"You are a helpful assistant desenigned to create a text output in which you got through {spec} and {info} and then generate an output which have all the architecht of spec and incorporate the values and insight from info only."},
        {"role": "system", "content": f"Based on the information provided about the {info} data product and {spec}, create a new specification text that covers the aspects of {spec} and using the information from {info} and {spec} and {info} both are different data products so give the output only based on the {info} dont mention the name of the data product from {spec} in the output.The output which is generated I want it in the same format as {spec} "},
        {"role": "user", "content": "give me the output"}
    ]
)
print(response.choices[0].message.content)
# Out:
# **Description of Data Models Used**
#
# This structured representation outlines the stages and progression of a marketing campaign's funnel, providing insights into the flow of potential customers through various stages, from awareness to conversion:
#
# 1. Entity-Relationship Model:
#    - Depicts the connections between different campaign entities, tracking customer engagements, touchpoints, and responses throughout the marketing funnel.
#
# 2. Funnel Journey Model:
#    - Maps the customer's journey, capturing the sequential steps from initial awareness to the final conversion, identifying bottlenecks and dropout points.
#
# 3. Conversion Prediction Model:
#    - Utilizes predictive analytics to estimate conversion probabilities at each funnel stage, enabling the allocation of resources to the most effective strategies.
#
# 4. Attribution Model:
# ...

# %%
response = client.chat.completions.create(
    model="gpt-4-1106-preview",
    messages=[
        {"role": "system", "content": f"Based on the information provided about the {info} data product and its specifications, create a new specification text similar to {spec}. Incorporate the insights from {info} while ensuring that the output reflects the essence of the {info} data product. Avoid mentioning specific details from other data products to maintain focus on {info} and its unique features. Ensure that the output aligns with the architecture outlined in {spec}."},
        {"role": "user", "content": "give me the output"}
    ]
)
print(response.choices[0].message.content)
# Out:
# The Campaign Funnel Data Product (campaign-funnel-dp) is a robust analytical tool that meticulously charts the journey of prospective customers through the marketing funnel, from initial awareness to the ultimate conversion. This dynamic data product is carefully crafted to provide marketers and business strategists with a structured visualization of the campaign stages, harnessing data from multiple touchpoints across the marketing spectrum.
#
# With its active state and ongoing evolution, the campaign-funnel-dp has reached version 0.6, signifying the incorporation of user feedback and enhancements such as the addition of new tags to enrich relevance and searchability. Its latest update, managed by the meticulous oversight of contributors like Yogesh Khangode, demonstrates a commitment to continuous refinement and improvement.
#
# ...

# %%
with open('finally.json', 'r') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# [{'name': 'Overview of the Data Product',
#   'example content': 'The Customer 360 Data Product represents a transformative solution designed to empower organizations with a holistic and unified view of their customers. By consolidating data from various touchpoints and sources, this product aims to provide deep insights into customer behavior, preferences, and interactions. The comprehensive customer profiles generated enable businesses to enhance customer experiences, optimize marketing strategies, and make informed, data-driven decisions.',
#   'data function': ''},
#  {'name': 'Purpose and Objectives',
#   'example content': 'The primary purpose of the Customer 360 Data Product is to equip organizations with a powerful tool that facilitates a nuanced understanding of their customer base. By aggregating and analyzing diverse datasets, the product aims to achieve the following objectives:',
#   'subsection': [{'name': 'Enhance Customer Engagement',
# ...

# %%
def deconstruct(data):
    if type(data['content']) == str:
        print(data['content'])
    elif type(data['content']) == dict:
        for key, value in data['content'].items():
            print(key, value)
            deconstruct({'content': value})

# %%
def deconstruct(data):
    if isinstance(data, dict):
        for key, value in data.items():
            if isinstance(value, str):
                pass  
            elif isinstance(value, list):
                for item in value:
                    deconstruct(item)
            elif isinstance(value, dict):
                deconstruct(value)
    elif isinstance(data, list):
        for item in data:
            deconstruct(item)

# %%
os.environ['METIS_TOKEN'] = 'YXRsYXNfZTc1YzFhNjZhZTQwNmRiN2QyZjQ1MWIyMTZiMTA2NjQuODljMGJjZjUtNzVhMC00ZDFlLThkZGYtYWFiM2JlZWI0NDRl'

# %%
os.environ['OPENAI_TOKEN'] = "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"

# %%
import requests

url = 'https://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/fdc5c178-8d6f-4bf1-9408-b8467e6f6923'
username = 'Balaji'
api_token = os.environ.get('METIS_TOKEN')
response = requests.get(url, auth=(username, api_token))

# %%
info = str(response.json())
info
# Out:
# '{\'id\': \'fdc5c178-8d6f-4bf1-9408-b8467e6f6923\', \'name\': \'customer-insights-dp\', \'state\': \'active\', \'manifestVersion\': \'v1alpha\', \'displayName\': \'customer-insights-dp\', \'fullyQualifiedName\': \'customer-insights-dp\', \'description\': \'This  provides detailed information about customer behavior, preferences, and trends, obtained through thorough data processing methods. It includes comprehensive insights into customer interactions, purchases, demographics, and other relevant metrics, enabling businesses to gain a deep understanding of their customer base and tailor their strategies accordingly.\', \'version\': 1.8, \'updatedAt\': 1708495826831, \'updatedBy\': \'yogeshkhangode\', \'href\': \'http://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/fdc5c178-8d6f-4bf1-9408-b8467e6f6923\', \'changeDescription\': {\'fieldsAdded\': [{\'name\': \'tags\', \'newValue\': \'[{"tagFQN":"dataos.dataos:product:data:customer-insights-dp","source":"Classification","labelType"
# ...

# %%
metis_token = os.environ.get('YXRsYXNfZTc1YzFhNjZhZTQwNmRiN2QyZjQ1MWIyMTZiMTA2NjQuODljMGJjZjUtNzVhMC00ZDFlLThkZGYtYWFiM2JlZWI0NDRl')
openai_api_token = os.environ.get('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')

# %%
data_function = """
def metis_request():
    url = 'https://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/fdc5c178-8d6f-4bf1-9408-b8467e6f6923'
    username = 'Balaji'
    api_token = os.environ.get('METIS_API_TOKEN')
    response = requests.get(url, auth=(username, api_token))
    return response

def openai_request():
    client = openai.Client(api_key=os.environ.get("OPENAI_TOKEN"))
    response = client.chat.completions.create(
        model="gpt-4-1106-preview",
        messages=[
            {"role": "system", "content": "Based on the information provided from response and the section. You need to generate a output which is exactly same as the content but the information should only be used from responses"},
            {"role": "user", "content": "give me the output"}
        ]
    )
    return response
"""

# %%
import re
import json
import requests
import openai
import os

# %%
os.environ['METIS_TOKEN'] = 'YXRsYXNfZTc1YzFhNjZhZTQwNmRiN2QyZjQ1MWIyMTZiMTA2NjQuODljMGJjZjUtNzVhMC00ZDFlLThkZGYtYWFiM2JlZWI0NDRl'
os.environ['OPENAI_TOKEN'] = "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"

# %%
with open('final2.json', 'r') as file:
    data = json.load(file)

# %%
def data_dataproductoverview():
    print("caliing metis for data product overview information")
    url = 'https://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/fdc5c178-8d6f-4bf1-9408-b8467e6f6923'
    username = 'Balaji'
    api_token = os.environ.get('METIS_API_TOKEN')
    info = requests.get(url, auth=(username, api_token))
    return str(info.json())

# %%
def doexample(info,sec):
    print("Info:", info)
    print("Section:", sec)
    client = openai.Client(api_key=os.environ.get("OPENAI_TOKEN"))
    response = client.chat.completions.create(
        model="gpt-4-1106-preview",
        messages=[
            {"role": "system", "content": "Based on the information provided from the sec and info. You need to generate an output which is has the same architech and also matches the section. The information should be used from response"},
            {"role": "user", "content": "give me the output"}
        ]
    )
    try:
        text = response.choices[0].message['content']
    except (TypeError, AttributeError):
        text = response.choices[0].message.content
    return text

# %%
def build_document(template,output):
#     if output is None:
#          output = []
    for sec in template:
        title = sec.get("name","empty title")
        df = sec.get("data_function","")
        ex = sec.get("example_content","")
        if len(df)>0:
            res = eval(df)
            content = doexample(ex,res)
            strpart = title + "\n" + content
            output.append(strpart)
        sub = sec.get("subsection",[])
        for s in sub:
            build_document([s],output)
    return output

# %%
output_document = build_document(data)
for part in output_document:
    print(part)
# Out:
# Info: The Customer 360 Data Product represents a transformative solution designed to empower organizations with a holistic and unified view of their customers. By consolidating data from various touchpoints and sources, this product aims to provide deep insights into customer behavior, preferences, and interactions. The comprehensive customer profiles generated enable businesses to enhance customer experiences, optimize marketing strategies, and make informed, data-driven decisions.
# Section: <function data_dataproductoverview at 0x7f992a7ffe50>
# Overview of the Data Product
# I'm sorry, but you haven't provided any specific information or context from which I could generate an output. Please provide the details or the information from the SEC (U.S. Securities and Exchange Commission) that you are referring to, or describe the architecture and section that you want to be matched, so I can assist you appropriately.

# %%
with open('finally.json', 'r') as file:
    json_data = json.load(file)

for section in json_data:
    data_function = section.get('data_function')
    
    if data_function:
        try:
            exec(data_function)
            if 'metis_request' in data_function:
                response = metis_request()
            elif 'openai_request' in data_function:
                response = openai_request()
                
            print(response)
        except Exception as e:
            print(f"Error executing data_function: {e}")
# Out:
# <Response [401]>

# %%
def data_dataproductoverview():
    print("calling Metis for data product overview information")
    url = 'https://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/fdc5c178-8d6f-4bf1-9408-b8467e6f6923'
    username = 'Balaji'
    api_token = os.environ.get('METIS_API_TOKEN')
    response = requests.get(url, auth=(username, api_token))
    return str(response.json())

def doexample(spec, info):
    client = openai.Client(api_key=os.environ.get("OPENAI_TOKEN"))
    response = client.chat.completions.create(
        model="gpt-4-1106-preview",
        messages=[
            {"role": "system", "content": "Based on the information provided from response and the section. You need to generate an output which is exactly same as the content but the information should only be used from responses"},
            {"role": "user", "content": "give me the output"}
        ]
    )
    try:
        text = response.choices[0].message['content']
    except (TypeError, AttributeError):
        text = response.choices[0].message.content
    return text

def build_document(template, output=None):
    if output is None:
        output = []
    for sec in template:
        title = sec.get("name", "empty title")
        df = sec.get("data_function", "")
        ex = sec.get("example_content", "")
        if len(df) > 0:
            print("Data function:", df)
            res = eval(df)
            content = doexample(ex, res)
            strpart = title + "\n" + content
            output.append(strpart)
        sub = sec.get("subsection", [])
        for s in sub:
            build_document([s], output)
    return output

# Load JSON data from file
with open('finally.json', 'r') as file:
    data = json.load(file)

# Build document
output_document = build_document(data)

# Print the output document
for part in output_document:
    print(part)
# Out:
# Data function: data_dataproductoverview
# Data function: def metis_request():
#     url = 'https://cheerful-maggot.dataos.app/metis/api/v1/dataProducts/fdc5c178-8d6f-4bf1-9408-b8467e6f6923'
#     username = 'Balaji'
#     api_token = os.environ.get('METIS_API_TOKEN')
#     response = requests.get(url, auth=(username, api_token))
#     return response
#
# def openai_request():
#     import openai
#     client = openai.Client(api_key=os.environ.get("OPENAI_TOKEN"))
#     response = client.chat.completions.create(
#         model="gpt-4-1106-preview",
#         messages=[
#             {"role": "system", "content": "Based on the information provided from response and the section. You need to generate a output which is exactly same as the content but the information should only be used from responses"},
#             {"role": "user", "content": "give me the output"}
#         ]
#     )
#     return response
# Traceback (most recent call last):
#
# ...
